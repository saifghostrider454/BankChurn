# %% [markdown]
# ### Business Context

# %% [markdown]
# Context
#
# A dataset which contain some customers who are withdrawing their account from the bank due to some loss and other issues with the help this data we try to analyse and maintain accuracy.
#
# Content
#
# What's inside is more than just rows and columns. Make it easy for others to get started by describing how you acquired the data and what time period it represents, too.
#
# Acknowledgements
#
# We wouldn't be here without the help of others. If you owe any attributions or thanks, include them here along with any citations of past research.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

sns.set()

# %% [markdown]
# ### Importing DataSet

# %%
FILE_PATH = "../data/raw/train.csv"
df = pd.read_csv(FILE_PATH)

# %% [markdown]
# ### Seeing Dataset for the First Time

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 773          774         0       3
# 149          150         0       2
# 347          348         1       3
# 747          748         1       2
# 799          800         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 773                                    Elias, Mr. Dibo    male   NaN      0
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.0      0
# 347          Davison, Mrs. Thomas Henry (Mary E Finck)  female   NaN      1
# 747                              Sinkkonen, Miss. Anna  female  30.0      0
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
#
#      Parch  Ticket    Fare Cabin Embarked
# 773      0    2674   7.225   NaN        C
# 149      0  244310  13.000   NaN        S
# 347      0  386525  16.100   NaN        S
# 747      0  250648  13.000   NaN        S
# 799      1  345773  24.150   NaN        S

# %% [markdown]
# ### About Dataset

# %%
print(f"This Dataset Contains {df.shape[0]} Rows and {df.shape[1]} Columns")
# Out:
# This Dataset Contains 891 Rows and 12 Columns

# %% [markdown]
# ### Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Dataset Description

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ab018_row0_col0, #T_ab018_row0_col1, #T_ab018_row0_col2, #T_ab018_row0_col3, #T_ab018_row0_col4, #T_ab018_row0_col5, #T_ab018_row0_col6, #T_ab018_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ab018_row1_col0, #T_ab018_row5_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_ab018_row1_col1, #T_ab018_row1_col2, #T_ab018_row1_col4, #T_ab018_row1_col5, #T_ab018_row2_col1, #T_ab018_row2_col2, #T_ab018_row2_col4, #T_ab018_row2_col5, #T_ab018_row3_col0, #T_ab018_row3_col1, #T_ab018_row3_col2, #T_ab018_row3_col3, #T_ab018_row3_col4, #T_ab018_row3_col5, #T_ab018_row3_col6, #T_ab018_row4_col1, #T_ab018_row4_col2, #T_ab018_row4_col4, #T_ab018_row4_col5, #T_ab018_row5_col1, #T_ab018_row5_col2, #T_ab018_row5_col4, #T_ab018_row5_col5, #T_ab018_row6_col1, #T_ab018_row6_col2, #T_ab018_row6_col4, #T_ab018_row6_col5, #T_ab018_row7_col1, #T_ab018_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ab018_row1_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_ab018_row1_col6, #T_ab018_row5_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ab018_row2_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_ab018_row2_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ab018_row2_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ab018_row4_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_ab018_row4_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ab018_row4_col6, #T_ab018_row7_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ab018_row5_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_ab018_row6_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_ab018_row6_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_ab018_row6_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_ab018_row7_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_ab018_row7_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ab018_row7_col6 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab018">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab018_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_ab018_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_ab018_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_ab018_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_ab018_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_ab018_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_ab018_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab018_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ab018_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_ab018_row0_col1" class="data row0 col1" >891.000000</td>
#       <td id="T_ab018_row0_col2" class="data row0 col2" >891.000000</td>
#       <td id="T_ab018_row0_col3" class="data row0 col3" >714.000000</td>
#       <td id="T_ab018_row0_col4" class="data row0 col4" >891.000000</td>
#       <td id="T_ab018_row0_col5" class="data row0 col5" >891.000000</td>
#       <td id="T_ab018_row0_col6" class="data row0 col6" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ab018_row1_col0" class="data row1 col0" >446.000000</td>
#       <td id="T_ab018_row1_col1" class="data row1 col1" >0.383838</td>
#       <td id="T_ab018_row1_col2" class="data row1 col2" >2.308642</td>
#       <td id="T_ab018_row1_col3" class="data row1 col3" >29.699118</td>
#       <td id="T_ab018_row1_col4" class="data row1 col4" >0.523008</td>
#       <td id="T_ab018_row1_col5" class="data row1 col5" >0.381594</td>
#       <td id="T_ab018_row1_col6" class="data row1 col6" >32.204208</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ab018_row2_col0" class="data row2 col0" >257.353842</td>
#       <td id="T_ab018_row2_col1" class="data row2 col1" >0.486592</td>
#       <td id="T_ab018_row2_col2" class="data row2 col2" >0.836071</td>
#       <td id="T_ab018_row2_col3" class="data row2 col3" >14.526497</td>
#       <td id="T_ab018_row2_col4" class="data row2 col4" >1.102743</td>
#       <td id="T_ab018_row2_col5" class="data row2 col5" >0.806057</td>
#       <td id="T_ab018_row2_col6" class="data row2 col6" >49.693429</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_ab018_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_ab018_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_ab018_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_ab018_row3_col3" class="data row3 col3" >0.420000</td>
#       <td id="T_ab018_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_ab018_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_ab018_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_ab018_row4_col0" class="data row4 col0" >223.500000</td>
#       <td id="T_ab018_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_ab018_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_ab018_row4_col3" class="data row4 col3" >20.125000</td>
#       <td id="T_ab018_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_ab018_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_ab018_row4_col6" class="data row4 col6" >7.910400</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_ab018_row5_col0" class="data row5 col0" >446.000000</td>
#       <td id="T_ab018_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_ab018_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_ab018_row5_col3" class="data row5 col3" >28.000000</td>
#       <td id="T_ab018_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_ab018_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_ab018_row5_col6" class="data row5 col6" >14.454200</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_ab018_row6_col0" class="data row6 col0" >668.500000</td>
#       <td id="T_ab018_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_ab018_row6_col2" class="data row6 col2" >3.000000</td>
#       <td id="T_ab018_row6_col3" class="data row6 col3" >38.000000</td>
#       <td id="T_ab018_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_ab018_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_ab018_row6_col6" class="data row6 col6" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab018_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_ab018_row7_col0" class="data row7 col0" >891.000000</td>
#       <td id="T_ab018_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_ab018_row7_col2" class="data row7 col2" >3.000000</td>
#       <td id="T_ab018_row7_col3" class="data row7 col3" >80.000000</td>
#       <td id="T_ab018_row7_col4" class="data row7 col4" >8.000000</td>
#       <td id="T_ab018_row7_col5" class="data row7 col5" >6.000000</td>
#       <td id="T_ab018_row7_col6" class="data row7 col6" >512.329200</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Finding Nulls

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ### Visualizing Data and understanding patterns

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 51            52         0       3  Nosworthy, Mr. Richard Cater  male  21.0
# 86            87         0       3        Ford, Mr. William Neal  male  16.0
# 648          649         0       3            Willey, Mr. Edward  male   NaN
#
#      SibSp  Parch         Ticket    Fare Cabin Embarked
# 51       0      0     A/4. 39886   7.800   NaN        S
# 86       1      3     W./C. 6608  34.375   NaN        S
# 648      0      0  S.O./P.P. 751   7.550   NaN        S

# %%
pd.crosstab(df.Sex, df.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_56d61_row0_col0, #T_56d61_row0_col2, #T_56d61_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_56d61_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_56d61_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_56d61_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_56d61_row2_col0, #T_56d61_row2_col1, #T_56d61_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_56d61">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_56d61_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_56d61_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_56d61_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56d61_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_56d61_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_56d61_row0_col1" class="data row0 col1" >233</td>
#       <td id="T_56d61_row0_col2" class="data row0 col2" >314</td>
#     </tr>
#     <tr>
#       <th id="T_56d61_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_56d61_row1_col0" class="data row1 col0" >468</td>
#       <td id="T_56d61_row1_col1" class="data row1 col1" >109</td>
#       <td id="T_56d61_row1_col2" class="data row1 col2" >577</td>
#     </tr>
#     <tr>
#       <th id="T_56d61_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_56d61_row2_col0" class="data row2 col0" >549</td>
#       <td id="T_56d61_row2_col1" class="data row2 col1" >342</td>
#       <td id="T_56d61_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df.Sex, df.Pclass], df.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c49db_row0_col0, #T_c49db_row1_col2, #T_c49db_row4_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c49db_row0_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_c49db_row0_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_c49db_row1_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_c49db_row1_col1, #T_c49db_row4_col0 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_c49db_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_c49db_row2_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_c49db_row2_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_c49db_row3_col0 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_c49db_row3_col1 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_c49db_row3_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_c49db_row4_col2 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_c49db_row5_col0 {
#   background-color: #74ba66;
#   color: #f1f1f1;
# }
# #T_c49db_row5_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_c49db_row5_col2 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_c49db_row6_col0, #T_c49db_row6_col1, #T_c49db_row6_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c49db">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_c49db_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c49db_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c49db_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c49db_level0_row0" class="row_heading level0 row0" rowspan="3">female</th>
#       <th id="T_c49db_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_c49db_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_c49db_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_c49db_row0_col2" class="data row0 col2" >94</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_c49db_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_c49db_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_c49db_row1_col2" class="data row1 col2" >76</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_c49db_row2_col0" class="data row2 col0" >72</td>
#       <td id="T_c49db_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_c49db_row2_col2" class="data row2 col2" >144</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level0_row3" class="row_heading level0 row3" rowspan="3">male</th>
#       <th id="T_c49db_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_c49db_row3_col0" class="data row3 col0" >77</td>
#       <td id="T_c49db_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_c49db_row3_col2" class="data row3 col2" >122</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_c49db_row4_col0" class="data row4 col0" >91</td>
#       <td id="T_c49db_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_c49db_row4_col2" class="data row4 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_c49db_row5_col0" class="data row5 col0" >300</td>
#       <td id="T_c49db_row5_col1" class="data row5 col1" >47</td>
#       <td id="T_c49db_row5_col2" class="data row5 col2" >347</td>
#     </tr>
#     <tr>
#       <th id="T_c49db_level0_row6" class="row_heading level0 row6" >All</th>
#       <th id="T_c49db_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_c49db_row6_col0" class="data row6 col0" >549</td>
#       <td id="T_c49db_row6_col1" class="data row6 col1" >342</td>
#       <td id="T_c49db_row6_col2" class="data row6 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(8, 4))  # Adjust the figure size as needed
sns.catplot(x='Pclass', y='Survived', hue='Sex', data=df, kind='point', palette="pastel", ci=None, dodge=True)

# Set labels and title
plt.xlabel("Passenger Class")
plt.ylabel("Survival Probability")
plt.title("Survival Probability by Passenger Class and Gender")


# Show the plot
plt.show()

# %% [markdown]
# We use Catplot in this case, because they make the seperation of categorical values easy.
#
# Looking at the CrossTab and the Catplot, we can easily infer that survival for Women from Pclass1 is about 95-96%, as only 3 out of 94 Women from Pclass1 died.
#
# It is evident that irrespective of Pclass, Women were given first priority while rescue. Even Men from Pclass1 have a very low survival rate.
#
# Looks like Pclass is also an important feature. Lets analyse other features.

# %% [markdown]
# ### Age --> Continuous Feature

# %%
age = {
    'age': ['Oldest', 'Youngest', 'Mean'],
    'value': [df['Age'].max(), df['Age'].min(), df['Age'].mean()]
}
age_df = pd.DataFrame(age)
age_df.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5decb_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_5decb_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5decb_row2_col1 {
#   background-color: #a1d066;
#   color: #000000;
# }
# </style>
# <table id="T_5decb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5decb_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_5decb_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5decb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5decb_row0_col0" class="data row0 col0" >Oldest</td>
#       <td id="T_5decb_row0_col1" class="data row0 col1" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5decb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5decb_row1_col0" class="data row1 col0" >Youngest</td>
#       <td id="T_5decb_row1_col1" class="data row1 col1" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_5decb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5decb_row2_col0" class="data row2 col0" >Mean</td>
#       <td id="T_5decb_row2_col1" class="data row2 col1" >29.699118</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=df,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x="Sex",y="Age", hue="Survived", data=df,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# Observations:
#
# 1)The number of children increases with Pclass and the survival rate for passenegers below Age 10(i.e children) looks to be good irrespective of the Pclass.
#
# 2)Survival chances for Passenegers aged 20-50 from Pclass1 is high and is even better for Women.
#
# 3)For males, the survival chances decreases with an increase in age.
#
# As we had seen earlier, the Age feature has 177 null values. To replace these NaN values, we can assign them the mean age of the dataset.
#
# But the problem is, there were many people with many different ages. We just cant assign a 4 year kid with the mean age that is 29 years. Is there any way to find out what age-band does the passenger lie??
#
# Bingo!!!!, we can check the Name feature. Looking upon the feature, we can see that the names have a salutation like Mr or Mrs. Thus we can assign the mean values of Mr and Mrs to the respective groups.
#
# ''What's In A Name??''---> Feature :p

# %%
df['Initial']=0
for i in df:
    df['Initial']=df.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_82105_row0_col0, #T_82105_row0_col1, #T_82105_row0_col3, #T_82105_row0_col4, #T_82105_row0_col5, #T_82105_row0_col7, #T_82105_row0_col8, #T_82105_row0_col12, #T_82105_row0_col15, #T_82105_row0_col16, #T_82105_row1_col2, #T_82105_row1_col6, #T_82105_row1_col9, #T_82105_row1_col10, #T_82105_row1_col11, #T_82105_row1_col13, #T_82105_row1_col14 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_82105_row0_col2, #T_82105_row0_col6, #T_82105_row0_col9, #T_82105_row0_col10, #T_82105_row0_col11, #T_82105_row0_col13, #T_82105_row0_col14, #T_82105_row1_col0, #T_82105_row1_col1, #T_82105_row1_col3, #T_82105_row1_col4, #T_82105_row1_col5, #T_82105_row1_col7, #T_82105_row1_col8, #T_82105_row1_col12, #T_82105_row1_col15, #T_82105_row1_col16 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_82105">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_82105_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_82105_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_82105_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_82105_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_82105_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_82105_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_82105_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_82105_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_82105_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_82105_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_82105_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_82105_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_82105_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_82105_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_82105_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_82105_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_82105_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82105_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_82105_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_82105_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_82105_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_82105_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_82105_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_82105_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_82105_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_82105_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_82105_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_82105_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_82105_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_82105_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_82105_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_82105_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_82105_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_82105_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_82105_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_82105_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_82105_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_82105_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_82105_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_82105_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_82105_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_82105_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_82105_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_82105_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_82105_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_82105_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_82105_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_82105_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_82105_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_82105_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_82105_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_82105_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_82105_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Okay so there are some misspelled Initials like Mlle or Mme that stand for Miss.
#
# I will replace them with Miss and same thing for other values.

# %%
df['Initial'].replace(
    ['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
    ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],
    inplace=True
    )

# %%
pd.DataFrame(df.groupby('Initial')['Age'].mean()).style.background_gradient(cmap='Blues') #lets check the average age by Initials
# Out:
# <style type="text/css">
# #T_a03c2_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a03c2_row1_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a03c2_row2_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_a03c2_row3_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_a03c2_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a03c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a03c2_level0_col0" class="col_heading level0 col0" >Age</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a03c2_level0_row0" class="row_heading level0 row0" >Master</th>
#       <td id="T_a03c2_row0_col0" class="data row0 col0" >4.574167</td>
#     </tr>
#     <tr>
#       <th id="T_a03c2_level0_row1" class="row_heading level0 row1" >Miss</th>
#       <td id="T_a03c2_row1_col0" class="data row1 col0" >21.860000</td>
#     </tr>
#     <tr>
#       <th id="T_a03c2_level0_row2" class="row_heading level0 row2" >Mr</th>
#       <td id="T_a03c2_row2_col0" class="data row2 col0" >32.739609</td>
#     </tr>
#     <tr>
#       <th id="T_a03c2_level0_row3" class="row_heading level0 row3" >Mrs</th>
#       <td id="T_a03c2_row3_col0" class="data row3 col0" >35.981818</td>
#     </tr>
#     <tr>
#       <th id="T_a03c2_level0_row4" class="row_heading level0 row4" >Other</th>
#       <td id="T_a03c2_row4_col0" class="data row4 col0" >45.888889</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
df.loc[(df.Age.isnull())&(df.Initial=='Mr'),'Age']=33
df.loc[(df.Age.isnull())&(df.Initial=='Mrs'),'Age']=36
df.loc[(df.Age.isnull())&(df.Initial=='Master'),'Age']=5
df.loc[(df.Age.isnull())&(df.Initial=='Miss'),'Age']=22
df.loc[(df.Age.isnull())&(df.Initial=='Other'),'Age']=46

# %%
df.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,5))
df[df['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
df[df['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# Observations:
#
# 1)The Toddlers(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
sns.catplot(x='Pclass',y='Survived',col='Initial',data=df, kind='point', palette="pastel", ci=None)
plt.show()

# %% [markdown]
# The Women and Child first policy thus holds true irrespective of the class.

# %% [markdown]
# ### Embarked --> Categorical Value

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a76d2_row0_col0, #T_a76d2_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_a76d2_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_a76d2_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_a76d2_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_a76d2_row0_col4, #T_a76d2_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_a76d2_row1_col0, #T_a76d2_row3_col0, #T_a76d2_row3_col1, #T_a76d2_row3_col2, #T_a76d2_row3_col3, #T_a76d2_row3_col4, #T_a76d2_row4_col0, #T_a76d2_row4_col2, #T_a76d2_row4_col3, #T_a76d2_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a76d2_row1_col1, #T_a76d2_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_a76d2_row1_col3, #T_a76d2_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_a76d2_row2_col0, #T_a76d2_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_a76d2_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_a76d2_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_a76d2_row2_col4, #T_a76d2_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_a76d2_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_a76d2_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_a76d2_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_a76d2_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_a76d2_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_a76d2_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_a76d2_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_a76d2_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_a76d2_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_a76d2_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_a76d2_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_a76d2_row7_col3, #T_a76d2_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_a76d2_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_a76d2_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_a76d2_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_a76d2_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_a76d2_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_a76d2_row9_col0, #T_a76d2_row9_col1, #T_a76d2_row9_col2, #T_a76d2_row9_col3, #T_a76d2_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a76d2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_a76d2_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_a76d2_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_a76d2_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_a76d2_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_a76d2_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_a76d2_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_a76d2_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_a76d2_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a76d2_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_a76d2_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_a76d2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a76d2_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_a76d2_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_a76d2_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_a76d2_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_a76d2_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_a76d2_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_a76d2_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_a76d2_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_a76d2_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_a76d2_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_a76d2_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_a76d2_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_a76d2_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_a76d2_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_a76d2_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_a76d2_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_a76d2_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_a76d2_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_a76d2_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a76d2_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_a76d2_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_a76d2_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_a76d2_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_a76d2_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_a76d2_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_a76d2_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_a76d2_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_a76d2_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_a76d2_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_a76d2_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_a76d2_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_a76d2_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_a76d2_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_a76d2_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_a76d2_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_a76d2_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_a76d2_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_a76d2_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_a76d2_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_a76d2_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_a76d2_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_a76d2_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_a76d2_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_a76d2_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_a76d2_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_a76d2_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_a76d2_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_a76d2_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_a76d2_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
sns.catplot(x='Embarked',y='Survived',data=df, kind='point')
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot(x='Embarked',data=df,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot(x='Embarked',hue='Sex',data=df,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot(x='Embarked',hue='Survived',data=df,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot(x='Embarked',hue='Pclass',data=df,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# Observations:
#
# 1)Maximum passenegers boarded from S. Majority of them being from Pclass3.
#
# 2)The Passengers from C look to be lucky as a good proportion of them survived. The reason for this maybe the rescue of all the Pclass1 and Pclass2 Passengers.
#
# 3)The Embark S looks to the port from where majority of the rich people boarded. Still the chances for survival is low here, that is because many passengers from Pclass3 around 81% didn't survive.
#
# 4)Port Q had almost 95% of the passengers were from Pclass3.

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',col='Embarked',data=df, kind='point')
plt.show()

# %% [markdown]
# Observations:
#
# 1)The survival chances are almost 1 for women for Pclass1 and Pclass2 irrespective of the Pclass.
#
# 2)Port S looks to be very unlucky for Pclass3 Passenegers as the survival rate for both men and women is very low.(Money Matters)
#
# 3)Port Q looks looks to be unlukiest for Men, as almost all were from Pclass 3.

# %% [markdown]
# ### Filling Embarked NaN
#
# As we saw that maximum passengers boarded from Port S, we replace NaN with S

# %%
df['Embarked'].fillna(value='S', inplace=True)

# %% [markdown]
# ### SibSip-->Discrete Feature
#
# This feature represents whether a person is alone or with his family members.
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife

# %%
pd.crosstab(df.SibSp, df.Survived).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d2d40_row0_col0, #T_d2d40_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d2d40_row1_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_d2d40_row1_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_d2d40_row2_col0, #T_d2d40_row4_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_d2d40_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d2d40_row3_col0, #T_d2d40_row3_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d2d40_row4_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d2d40_row5_col0, #T_d2d40_row5_col1, #T_d2d40_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d2d40_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_d2d40">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_d2d40_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d2d40_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2d40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2d40_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_d2d40_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2d40_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_d2d40_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2d40_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_d2d40_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2d40_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_d2d40_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2d40_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_d2d40_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2d40_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_d2d40_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d2d40_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_d2d40_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_d2d40_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df.SibSp, df.Embarked], df.Survived).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_85c6d_row0_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_85c6d_row0_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_85c6d_row1_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_85c6d_row1_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_85c6d_row2_col0, #T_85c6d_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_85c6d_row3_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_85c6d_row3_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_85c6d_row4_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_85c6d_row4_col1, #T_85c6d_row6_col1, #T_85c6d_row9_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_85c6d_row5_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_85c6d_row5_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_85c6d_row6_col0, #T_85c6d_row7_col0, #T_85c6d_row10_col1, #T_85c6d_row12_col1, #T_85c6d_row13_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_85c6d_row7_col1, #T_85c6d_row12_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_85c6d_row8_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_85c6d_row8_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_85c6d_row9_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_85c6d_row10_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_85c6d_row11_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_85c6d_row11_col1, #T_85c6d_row13_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# </style>
# <table id="T_85c6d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_85c6d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_85c6d_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="index_name level1" >Embarked</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85c6d_level0_row0" class="row_heading level0 row0" rowspan="3">0</th>
#       <th id="T_85c6d_level1_row0" class="row_heading level1 row0" >C</th>
#       <td id="T_85c6d_row0_col0" class="data row0 col0" >57</td>
#       <td id="T_85c6d_row0_col1" class="data row0 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row1" class="row_heading level1 row1" >Q</th>
#       <td id="T_85c6d_row1_col0" class="data row1 col0" >36</td>
#       <td id="T_85c6d_row1_col1" class="data row1 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row2" class="row_heading level1 row2" >S</th>
#       <td id="T_85c6d_row2_col0" class="data row2 col0" >305</td>
#       <td id="T_85c6d_row2_col1" class="data row2 col1" >135</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row3" class="row_heading level0 row3" rowspan="3">1</th>
#       <th id="T_85c6d_level1_row3" class="row_heading level1 row3" >C</th>
#       <td id="T_85c6d_row3_col0" class="data row3 col0" >17</td>
#       <td id="T_85c6d_row3_col1" class="data row3 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row4" class="row_heading level1 row4" >Q</th>
#       <td id="T_85c6d_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_85c6d_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row5" class="row_heading level1 row5" >S</th>
#       <td id="T_85c6d_row5_col0" class="data row5 col0" >74</td>
#       <td id="T_85c6d_row5_col1" class="data row5 col1" >71</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row6" class="row_heading level0 row6" rowspan="3">2</th>
#       <th id="T_85c6d_level1_row6" class="row_heading level1 row6" >C</th>
#       <td id="T_85c6d_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_85c6d_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row7" class="row_heading level1 row7" >Q</th>
#       <td id="T_85c6d_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_85c6d_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row8" class="row_heading level1 row8" >S</th>
#       <td id="T_85c6d_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_85c6d_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row9" class="row_heading level0 row9" >3</th>
#       <th id="T_85c6d_level1_row9" class="row_heading level1 row9" >S</th>
#       <td id="T_85c6d_row9_col0" class="data row9 col0" >12</td>
#       <td id="T_85c6d_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row10" class="row_heading level0 row10" rowspan="2">4</th>
#       <th id="T_85c6d_level1_row10" class="row_heading level1 row10" >Q</th>
#       <td id="T_85c6d_row10_col0" class="data row10 col0" >4</td>
#       <td id="T_85c6d_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level1_row11" class="row_heading level1 row11" >S</th>
#       <td id="T_85c6d_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_85c6d_row11_col1" class="data row11 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row12" class="row_heading level0 row12" >5</th>
#       <th id="T_85c6d_level1_row12" class="row_heading level1 row12" >S</th>
#       <td id="T_85c6d_row12_col0" class="data row12 col0" >5</td>
#       <td id="T_85c6d_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_85c6d_level0_row13" class="row_heading level0 row13" >8</th>
#       <th id="T_85c6d_level1_row13" class="row_heading level1 row13" >S</th>
#       <td id="T_85c6d_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_85c6d_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot(x='SibSp',y='Survived',data=df,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(df.SibSp, df.Pclass).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_51e65_row0_col0, #T_51e65_row0_col1, #T_51e65_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_51e65_row1_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_51e65_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_51e65_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_51e65_row2_col0, #T_51e65_row4_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_51e65_row2_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_51e65_row2_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_51e65_row3_col0, #T_51e65_row3_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_51e65_row3_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_51e65_row4_col0, #T_51e65_row4_col1, #T_51e65_row5_col0, #T_51e65_row5_col1, #T_51e65_row5_col2, #T_51e65_row6_col0, #T_51e65_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_51e65_row6_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_51e65">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_51e65_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_51e65_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_51e65_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51e65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51e65_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_51e65_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_51e65_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51e65_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_51e65_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_51e65_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51e65_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_51e65_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_51e65_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51e65_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_51e65_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_51e65_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51e65_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_51e65_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_51e65_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_51e65_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_51e65_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_51e65_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_51e65_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_51e65_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_51e65_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_51e65_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Observations:
#
# The barplot and factorplot shows that if a passenger is alone onboard with no siblings, he have 34.5% survival rate. The graph roughly decreases if the number of siblings increase. This makes sense. That is, if I have a family on board, I will try to save them instead of saving myself first. Surprisingly the survival for families with 5-8 members is 0%. The reason may be Pclass??
#
# The reason is Pclass. The crosstab shows that Person with SibSp>3 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.

# %% [markdown]
# ### Parch

# %%
pd.crosstab(df.Parch, df.Survived).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a1601_row0_col0, #T_a1601_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a1601_row1_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_a1601_row1_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_a1601_row2_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_a1601_row2_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_a1601_row3_col0, #T_a1601_row4_col1, #T_a1601_row6_col0, #T_a1601_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a1601_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_a1601_row4_col0, #T_a1601_row5_col0, #T_a1601_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_a1601">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_a1601_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a1601_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1601_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1601_row0_col0" class="data row0 col0" >445</td>
#       <td id="T_a1601_row0_col1" class="data row0 col1" >233</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1601_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_a1601_row1_col1" class="data row1 col1" >65</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1601_row2_col0" class="data row2 col0" >40</td>
#       <td id="T_a1601_row2_col1" class="data row2 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1601_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_a1601_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1601_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_a1601_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1601_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_a1601_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a1601_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1601_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_a1601_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df.Parch, df.Embarked], df.Survived).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_5beec_row0_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_5beec_row0_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_5beec_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_5beec_row1_col1, #T_5beec_row8_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_5beec_row2_col0, #T_5beec_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5beec_row3_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_5beec_row3_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_5beec_row4_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_5beec_row4_col1, #T_5beec_row7_col0, #T_5beec_row7_col1, #T_5beec_row9_col0, #T_5beec_row11_col1, #T_5beec_row12_col0, #T_5beec_row12_col1, #T_5beec_row14_col0, #T_5beec_row14_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5beec_row5_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_5beec_row5_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_5beec_row6_col0, #T_5beec_row11_col0, #T_5beec_row13_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_5beec_row6_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5beec_row8_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_5beec_row9_col1, #T_5beec_row10_col0, #T_5beec_row13_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5beec_row10_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_5beec">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_5beec_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5beec_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="index_name level1" >Embarked</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5beec_level0_row0" class="row_heading level0 row0" rowspan="3">0</th>
#       <th id="T_5beec_level1_row0" class="row_heading level1 row0" >C</th>
#       <td id="T_5beec_row0_col0" class="data row0 col0" >60</td>
#       <td id="T_5beec_row0_col1" class="data row0 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row1" class="row_heading level1 row1" >Q</th>
#       <td id="T_5beec_row1_col0" class="data row1 col0" >39</td>
#       <td id="T_5beec_row1_col1" class="data row1 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row2" class="row_heading level1 row2" >S</th>
#       <td id="T_5beec_row2_col0" class="data row2 col0" >346</td>
#       <td id="T_5beec_row2_col1" class="data row2 col1" >140</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row3" class="row_heading level0 row3" rowspan="3">1</th>
#       <th id="T_5beec_level1_row3" class="row_heading level1 row3" >C</th>
#       <td id="T_5beec_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_5beec_row3_col1" class="data row3 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row4" class="row_heading level1 row4" >Q</th>
#       <td id="T_5beec_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_5beec_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row5" class="row_heading level1 row5" >S</th>
#       <td id="T_5beec_row5_col0" class="data row5 col0" >36</td>
#       <td id="T_5beec_row5_col1" class="data row5 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row6" class="row_heading level0 row6" rowspan="3">2</th>
#       <th id="T_5beec_level1_row6" class="row_heading level1 row6" >C</th>
#       <td id="T_5beec_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_5beec_row6_col1" class="data row6 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row7" class="row_heading level1 row7" >Q</th>
#       <td id="T_5beec_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_5beec_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row8" class="row_heading level1 row8" >S</th>
#       <td id="T_5beec_row8_col0" class="data row8 col0" >35</td>
#       <td id="T_5beec_row8_col1" class="data row8 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row9" class="row_heading level0 row9" rowspan="2">3</th>
#       <th id="T_5beec_level1_row9" class="row_heading level1 row9" >C</th>
#       <td id="T_5beec_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_5beec_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row10" class="row_heading level1 row10" >S</th>
#       <td id="T_5beec_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_5beec_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row11" class="row_heading level0 row11" >4</th>
#       <th id="T_5beec_level1_row11" class="row_heading level1 row11" >S</th>
#       <td id="T_5beec_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_5beec_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row12" class="row_heading level0 row12" rowspan="2">5</th>
#       <th id="T_5beec_level1_row12" class="row_heading level1 row12" >Q</th>
#       <td id="T_5beec_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_5beec_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level1_row13" class="row_heading level1 row13" >S</th>
#       <td id="T_5beec_row13_col0" class="data row13 col0" >3</td>
#       <td id="T_5beec_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5beec_level0_row14" class="row_heading level0 row14" >6</th>
#       <th id="T_5beec_level1_row14" class="row_heading level1 row14" >S</th>
#       <td id="T_5beec_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_5beec_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Fare --> Continous Feature

# %%
print('Highest Fare was:',df['Fare'].max())
print('Lowest Fare was:',df['Fare'].min())
print('Average Fare was:',df['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.204207968574636

# %% [markdown]
# The lowest fare is 0.0. Wow!! a free luxorious ride

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(df[df['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(df[df['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(df[df['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also continous, we can convert into discrete values by using binning.

# %% [markdown]
# ### Observations in a Nutshell for all features:
#
# Sex: The chance of survival for women is high as compared to men.
#
# Pclass:There is a visible trend that being a 1st class passenger gives you better chances of survival. The survival rate for Pclass3 is very low. For women, the chance of survival from Pclass1 is almost 1 and is high too for those from Pclass2. Money Wins!!!.
#
# Age: Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# Embarked: This is a very interesting feature. The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S. Passengers at Q were all from Pclass3.
#
# Parch+SibSp: Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %% [markdown]
# ### Correlation Between The Features

# %%
sns.heatmap(df.select_dtypes(exclude=object).corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ### Interpreting The Heatmap
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings. Before understanding the plot, let us see what exactly correlation is.
#
# POSITIVE CORRELATION: If an increase in feature A leads to increase in feature B, then they are positively correlated. A value 1 means perfect positive correlation.
#
# NEGATIVE CORRELATION: If an increase in feature A leads to decrease in feature B, then they are negatively correlated. A value -1 means perfect negative correlation.
#
# Now lets say that two features are highly or perfectly correlated, so the increase in one leads to increase in the other. This means that both the features are containing highly similar information and there is very little or no variance in information. This is known as MultiColinearity as both of them contains almost the same information.
#
# So do you think we should use both of them as one of them is redundant. While making or training models, we should try to eliminate redundant features as it reduces training time and many such advantages.
#
# Now from the above heatmap,we can see that the features are not much correlated. The highest correlation is between SibSp and Parch i.e 0.41. So we can carry on with all features.

# %% [markdown]
# ### Part2: Feature Engineering and Data Cleaning
# Now what is Feature Engineering?
#
# Whenever we are given a dataset with features, it is not necessary that all the features will be important. There maybe be many redundant features which should be eliminated. Also we can get or add new features by observing or extracting information from other features.
#
# An example would be getting the Initals feature using the Name Feature. Lets see if we can get any new features and eliminate a few. Also we will tranform the existing relevant features to suitable form for Predictive Modeling.

# %%
df['Age_band']=0
df.loc[df['Age']<=16,'Age_band']=0
df.loc[(df['Age']>16)&(df['Age']<=32),'Age_band']=1
df.loc[(df['Age']>32)&(df['Age']<=48),'Age_band']=2
df.loc[(df['Age']>48)&(df['Age']<=64),'Age_band']=3
df.loc[df['Age']>64,'Age_band']=4

# %%
df['Age_band'].value_counts().to_frame().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3dd68_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3dd68_row1_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_3dd68_row2_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_3dd68_row3_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3dd68_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_3dd68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dd68_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_band</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dd68_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3dd68_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_3dd68_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3dd68_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
#       <th id="T_3dd68_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_3dd68_row2_col0" class="data row2 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_3dd68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3dd68_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_3dd68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3dd68_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='Age_band',y='Survived',data=df,col='Pclass', kind='point')
plt.show()

# %% [markdown]
# True that..the survival rate decreases as the age increases irrespective of the Pclass

# %%
df['Family_Size'] = df['SibSp'] + df['Parch'] + 1

# %%
sns.catplot(x='Family_Size', y='Survived', hue='Sex', data=df, kind='point', col='Pclass')

plt.show()

# %%
df['Fare_Range']=pd.qcut(df['Fare'],4)
df.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8529e_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8529e_row1_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8529e_row2_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_8529e_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8529e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8529e_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8529e_level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#       <td id="T_8529e_row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>
#     <tr>
#       <th id="T_8529e_level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#       <td id="T_8529e_row1_col0" class="data row1 col0" >0.303571</td>
#     </tr>
#     <tr>
#       <th id="T_8529e_level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#       <td id="T_8529e_row2_col0" class="data row2 col0" >0.454955</td>
#     </tr>
#     <tr>
#       <th id="T_8529e_level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#       <td id="T_8529e_row3_col0" class="data row3 col0" >0.581081</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As discussed above, we can clearly see that as the fare_range increases, the chances of survival increases.
#
# Now we cannot pass the Fare_Range values as it is. We should convert it into singleton values same as we did in Age_Band

# %%
df['Fare_cat']=0
df.loc[df['Fare']<=7.91,'Fare_cat']=0
df.loc[(df['Fare']>7.91)&(df['Fare']<=14.454),'Fare_cat']=1
df.loc[(df['Fare']>14.454)&(df['Fare']<=31),'Fare_cat']=2
df.loc[(df['Fare']>31)&(df['Fare']<=513),'Fare_cat']=3

# %%
sns.catplot(x='Fare_cat', y='Survived', data=df, hue='Sex', kind='point')

plt.show()

# %% [markdown]
# Clearly, as the Fare_cat increases, the survival chances increases. This feature may become an important feature during modeling along with the Sex.

# %% [markdown]
# ### Converting String Values into Numeric
# Since we cannot pass strings to a machine learning model, we need to convert features like Sex, Embarked, etc into numeric values.

# %%
df['Sex'].replace(['male','female'],[0,1],inplace=True)
df['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
df['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %% [markdown]
# #### Dropping UnNeeded Features
# Name--> We don't need name feature as it cannot be converted into any categorical value.
#
# Age--> We have the Age_band feature, so no need of this.
#
# Ticket--> It is any random string that cannot be categorised.
#
# Fare--> We have the Fare_cat feature, so unneeded
#
# Cabin--> A lot of NaN values and also many passengers have multiple cabins. So this is a useless feature.
#
# Fare_Range--> We have the fare_cat feature.
#
# PassengerId--> Cannot be categorised.

# %%
df.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Now the above correlation plot, we can see some positively related features. Some of them being SibSp andd Family_Size and Parch and Family_Size and some negative ones like Alone and Family_Size.
